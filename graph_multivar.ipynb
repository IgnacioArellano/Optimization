# %%
import numpy as np
import numpy.linalg as la
import scipy.optimize as sopt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %matplotlib qt
#%matplotlib inline

# %%
X = np.arange(-5, 5, 0.01)
xlen = len(X)
Y = np.arange(-5, 5, 0.01)
ylen = len(Y)
X, Y = np.meshgrid(X, Y)
R = X**2 + Y**2-2*X
fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, R, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
plt.show()

# %%
X = np.arange(-5, 5, 0.01)
xlen = len(X)
Y = np.arange(-5, 5, 0.01)
ylen = len(Y)
mini=100000
for i in range(0,xlen):
    for j in range(0,ylen):
        temp = X[i]**2 + Y[j]**2-2*X[i]
        if temp<mini:
            mini=temp
            x1min=X[i]
            x2min=Y[j]
print(mini,x1min,x2min)
# Out:
# -1.0 0.9999999999998721 -1.0658141036401503e-13

# %%
X = np.arange(-5, 5, 0.01)
xlen = len(X)
Y = np.arange(-5, 5, 0.01)
ylen = len(Y)
X, Y = np.meshgrid(X, Y)
R = X**2 - Y**2
fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, R, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
plt.show()

# %%
X = np.arange(-5, 5, 0.01)
xlen = len(X)
Y = np.arange(-5, 5, 0.01)
ylen = len(Y)
mini=100000
for i in range(0,xlen):
    for j in range(0,ylen):
        temp = X[i]**2 - Y[j]**2
        if temp<mini:
            mini=temp
            x1min=X[i]
            x2min=Y[j]
print(mini,x1min,x2min)
# Out:
# -25.0 -1.0658141036401503e-13 -5.0

# %%
X = np.arange(-2, 2, 0.01)
xlen = len(X)
Y = np.arange(-1, 3, 0.01)
ylen = len(Y)
X, Y = np.meshgrid(X, Y)
R = 100*(Y-X**2)**2 +(1- X)**2
fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, R, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
R2=100*(-0.5+1.5**2)**2 +(1+1.5)**2
ax.scatter(-1.5, -0.5 , R2)
plt.show()
