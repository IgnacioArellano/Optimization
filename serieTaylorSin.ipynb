# %%
# %matplotlib inline
import math
import numpy as np
import matplotlib.pyplot as plt

#calcula la sumatoria
def calcularSeno(x, n):
    seno = 0
    for i in range(n):
        signo = (-1)**i
        numerador = x**((2*i)+1)
        denom = math.factorial((2*i)+ 1)
        seno += (signo) *((numerador)/(denom))
    return seno

def showSeno(orden):
    for i in range(1,orden+1):
        senoCalculado = [calcularSeno(x,i) for x in stepX]
        ax.plot(stepX,senoCalculado)

    ax.set_ylim([-6,6])

    # acomodamos la leyenda
    leyenda = ['sin(x)']
    for i in range(1,orden+1):
        leyenda.append(f'Serie Taylor - {i} termino')
   
    ax.legend(leyenda, loc=3)
    plt.show()
    
# se declaran las longitudes
stepX = np.arange(-2*np.pi,2*np.pi,0.1)
x = np.sin(stepX)


fig, ax = plt.subplots()
ax.plot(stepX,x)
showSeno(6);

# %%
# %matplotlib inline
import math
import numpy as np
import matplotlib.pyplot as plt

#calcula la sumatoria
def calcularSeno(x, n):
    seno = 0
    for i in range(n):
        signo = (-1)**i
        numerador = (x-np.pi)**((2*i)+1)
        denom = math.factorial((2*i)+ 1)
        seno += -1*((signo) *((numerador)/(denom)))
    return seno

def showSeno(orden):
    for i in range(1,orden+1):
        senoCalculado = [calcularSeno(x,i) for x in stepX]
        ax.plot(stepX,senoCalculado)

    ax.set_ylim([-6,6])

    # acomodamos la leyenda
    leyenda = ['sin(x)']
    for i in range(1,orden+1):
        leyenda.append(f'Serie Taylor - {i} termino')
   
    ax.legend(leyenda, loc=3)
    plt.show()
    
# se declaran las longitudes
stepX = np.arange(-2*np.pi,2*np.pi,0.1)
x = np.sin(stepX)


fig, ax = plt.subplots()
ax.plot(stepX,x)
showSeno(6);
