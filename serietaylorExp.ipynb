# %%
import matplotlib.pyplot as plt
import numpy
import math 
orden = 3
x = list(range(-10,10))
xstep=(numpy.arange(-10,10.1, 0.1))



def factorial(n):
    fact = 1.0
    for num in range(2, n + 1):
        fact *= num
    return fact

def calculateSerieEx(orden, values):
    fx = []
    
    for i in range(0,orden+1):
        puntos = []
        if i==0:
            for x in values:
                puntos.append(math.exp(x))
            fx.append(puntos)
        else:
           
            for z in values:
                puntos.append((z**i)/factorial(i))
            fx.append(puntos)
    return(fx)
            
            
        


fx = calculateSerieEx(orden,xstep)


plt.plot(xstep,fx[0], label = "e^x", color = "orange")
plt.plot(xstep,fx[1], label="f\'(x)" , color = "red" )
plt.plot(xstep,fx[2], label = "f\'\'(x)" , color="blue")
plt.plot(xstep,fx[3], label = "f\'\'\'(x)" , color="green")
plt.ylim(ymax = 150, ymin = -150)

plt.legend(loc='upper left', frameon=False)
plt.show()
